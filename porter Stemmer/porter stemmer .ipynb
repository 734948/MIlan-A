# %%
a = input("Enter an word: ")
if x in a==("a","i","e","u","o"):
    print

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
  
ps = PorterStemmer()
 
# choose some words to be stemmed
words = ["program", "programs", "programmer", "programming", "programmers"]
 
for w in words:
    print(w, " : ", ps.stem(w))
# Out:
# program  :  program
# programs  :  program
# programmer  :  programm
# programming  :  program
# programmers  :  programm

# %%
def isvowel(x):
    if (x == 'a' or x == 'e' or x == 'i' or x == 'o' or x == 'u'):
        return "v"
    else:
        return "C"
a = input("Enter a string:   ")
for i in range(len(a)):
    b = isvowel(a[i])
    if a[i] == 'y':
        if i == 0:
            print(a[i], "C")
        else:
            print(a[i], not(isvowel(a[i-1]))) 
    else:
        print(a[i], isvowel(a[i]))

# %%
def isvowel(x):
    if (x == 'a' or x == 'e' or x == 'i' or x == 'o' or x == 'u'):
        return "V"
    else:
        return "C"
a = input("Enter a string:   ")
for i in range(len(a)):
    b = isvowel(a[i])
    if a[i] == 'y':
        if i == 0:
            print(a[i], "C")
        else:
            print(a[i], not(isvowel(a[i-1]))) 
    else:
        print(a[i], isvowel(a[i]))
# Out:
# Enter a string:   conclude
# c C
# o V
# n C
# c C
# l C
# u V
# d C
# e V

# %%
def isVowel(x):
    if x=='a' or x=='e' or x=='i' or x=='o' or x=='u':
        return True
    else:
        return False
str = input("Enter a word ")
flag = 'T'
str2 = ''
for i in range(len(str)):
    if str[i]=='y' and i==0:
        if flag != 'c':
            str2=str2+'c'
        print(str[i]," is consonant" )
        flag = 'c'
        
    elif str[i]=='y' and i>0:
        if not(isVowel(str[i-1])):
            if flag != 'v':
                str2=str2+'v'
            print (str[i]," is vowel")
            flag = 'v'
        else:
            if flag != 'c':
                str2=str2+'c'
            print (str[i]," is consonant")
            flag = 'c'
    elif isVowel(str[i]):
        if flag != 'v':
            str2=str2+'v'
        print (str[i]," is vowel")
        flag = 'v'
    elif not(isVowel(str[i])):
        if flag != 'c':
            str2=str2+'c'
        print (str[i]," is consonant")
        flag = 'c'
# Out:
# Enter a word happily
# h  is consonant
# a  is vowel
# p  is consonant
# p  is consonant
# i  is vowel
# l  is consonant
# y  is vowel

# %%
print(str2)
# Out:
# cvcvcv

# %%
import re

x = re.findall("vc", str2)

print(x)
m = len(x)
print("c","(vc)","^",m,"v")
# Out:
# ['vc', 'vc']
# c (vc) ^ 2 v

# %%
import pandas as pd
import numpy
data = pd.read_csv("spam.csv",encoding= 'latin-1')
data
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df = pd.DataFrame(data)
df = df.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4'], axis = 1)

# %%
x = len(df.v2)
x
# Out:
# 5572

# %%
df['new column'] = df.astype(str).sum(axis =1).str.len()
df
# Out:
#         v1                                                 v2  new column
# 0      ham  Go until jurong point, crazy.. Available only ...         114
# 1      ham                      Ok lar... Joking wif u oni...          32
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...         159
# 3      ham  U dun say so early hor... U c already then say...          52
# 4      ham  Nah I don't think he goes to usf, he lives aro...          64
# ...    ...                                                ...         ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...         165
# 5568   ham              Will Ì_ b going to esplanade fr home?          40
# 5569   ham  Pity, * was in mood for that. So...any other s...          60
# 5570   ham  The guy did some bitching but I acted like i'd...         128
# 5571   ham                         Rofl. Its true to its name          29
#
# [5572 rows x 3 columns]

# %%
import nltk
c1 = df.v2
tokens = c1.split(' ')
tokens = nltk.word_tokenize(c1)
len(tokens)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b1805cc847e1> in <module>
#       1 import nltk
#       2 c1 = df.v2
# ----> 3 tokens = c1.split(' ')
#       4 tokens = nltk.word_tokenize(c1)
#       5 len(tokens)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
import nltk
df['totalwords'] = df['v2'].nltk.apply(word_tokenize(v2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-67edb0d78f3d> in <module>
#       1 import nltk
# ----> 2 df['totalwords'] = df['v2'].nltk.apply(word_tokenize(v2))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'nltk'

# %%
s = df['v2'].str.split(expand=True).stack().value_counts()

# %%
s
# Out:
# to             2134
# you            1622
# I              1466
# a              1327
# the            1197
#                ...
# Eleven            1
# least5times       1
# Ache              1
# å£750             1
# FIFA              1
# Length: 15585, dtype: int64

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nanda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df['word']=df['v2'].str.split().str.len()
df['sentence']=df['v2'].str.count('[\w][\.!\?]').clip(lower=1)
df['no_of_sents']=df['v2'].apply(lambda x: len(nltk.sent_tokenize(x)))
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()
df
# Out:
#         v1                                                 v2  new column  \
# 0      ham  Go until jurong point, crazy.. Available only ...         114
# 1      ham                      Ok lar... Joking wif u oni...          32
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...         159
# 3      ham  U dun say so early hor... U c already then say...          52
# 4      ham  Nah I don't think he goes to usf, he lives aro...          64
# ...    ...                                                ...         ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...         165
# 5568   ham              Will Ì_ b going to esplanade fr home?          40
# 5569   ham  Pity, * was in mood for that. So...any other s...          60
# 5570   ham  The guy did some bitching but I acted like i'd...         128
# 5571   ham                         Rofl. Its true to its name          29
#
#       word  sentence  no_of_sents
# 0       20         3            2
# ...

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
  
ps = PorterStemmer()

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
  
ps = PorterStemmer()

words = ["programming"]
 
for w in words:
    print(w, " : ", ps.stem(w))
# Out:
# programming  :  program

# %%
df['v2'] = df['v2'].apply(lambda x : " ".join(x.lower() for x in x.split()))
df.head()
# Out:
#      v1                                                 v2  new column  word  \
# 0   ham  go until jurong point, crazy.. available only ...         114    20
# 1   ham                      ok lar... joking wif u oni...          32     6
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...         159    28
# 3   ham  u dun say so early hor... u c already then say...          52    11
# 4   ham  nah i don't think he goes to usf, he lives aro...          64    13
#
#    sentence  no_of_sents                                    Cleaned_message
# 0         3            2  Gojurongpoint,crazy..Availablebugisngreatworld...
# 1         2            2                           Oklar...Jokingwifuoni...
# 2         1            2  Freeentry2wklycompwinFACupfinaltkts21stMay2005...
# 3         2            1                  Udunsayearlyhor...Ucalreadysay...
# 4         1            1                 NahIthinkgoesusf,livesaroundthough

# %%
all_words = [x for x in pd.Series(''.join(df['v2']).split())]

# %%
nltk.FreqDist(all_words).most_common(25)
# Out:
# [('to', 2220),
#  ('i', 1803),
#  ('you', 1761),
#  ('a', 1400),
#  ('the', 1281),
#  ('and', 943),
#  ('u', 916),
#  ('in', 835),
#  ('is', 835),
#  ('my', 712),
#  ('for', 680),
#  ('your', 649),
#  ('of', 610),
#  ('me', 573),
#  ('have', 544),
#  ('call', 529),
#  ('on', 511),
#  ('2', 447),
#  ('are', 445),
#  ('that', 439),
#  ('it', 437),
#  ('or', 405),
#  ('but', 398),
#  ('at', 379),
#  ('so', 375)]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nanda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
import random
import string

stop_words = set(stopwords.words('english'))
df['Cleaned_message']=df['v2'].apply(lambda x:"".join(x for x in x.split() if x not in stop_words))
df.head()
# Out:
#      v1                                                 v2  new column  word  \
# 0   ham  go until jurong point, crazy.. available only ...         114    20
# 1   ham                      ok lar... joking wif u oni...          32     6
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...         159    28
# 3   ham  u dun say so early hor... u c already then say...          52    11
# 4   ham  nah i don't think he goes to usf, he lives aro...          64    13
#
#    sentence  no_of_sents                                    Cleaned_message
# 0         3            2  gojurongpoint,crazy..availablebugisngreatworld...
# 1         2            2                           oklar...jokingwifuoni...
# 2         1            2  freeentry2wklycompwinfacupfinaltkts21stmay2005...
# 3         2            1                  udunsayearlyhor...ucalreadysay...
# 4         1            1                  nahthinkgoesusf,livesaroundthough

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
words = [x for x in pd.Series(' '.join(df['Cleaned_message']).split())] 

for w in words:
    ps.stem(w)
    
df.head()


from nltk.tokenize import word_tokenize
  
def stem_sentences(sentence):
    tokens = sentence.split()
    stemmed_tokens = [ps.stem(token) for token in tokens]
    return ' '.join(stemmed_tokens)


df['Cleaned_message'] = df['Cleaned_message'].apply(stem_sentences)
df
# Out:
#         v1                                                 v2  new column  \
# 0      ham  go until jurong point, crazy.. available only ...         114
# 1      ham                      ok lar... joking wif u oni...          32
# 2     spam  free entry in 2 a wkly comp to win fa cup fina...         159
# 3      ham  u dun say so early hor... u c already then say...          52
# 4      ham  nah i don't think he goes to usf, he lives aro...          64
# ...    ...                                                ...         ...
# 5567  spam  this is the 2nd time we have tried 2 contact u...         165
# 5568   ham              will ì_ b going to esplanade fr home?          40
# 5569   ham  pity, * was in mood for that. so...any other s...          60
# 5570   ham  the guy did some bitching but i acted like i'd...         128
# 5571   ham                         rofl. its true to its name          29
#
#       word  sentence  no_of_sents  \
# 0       20         3            2
# ...
